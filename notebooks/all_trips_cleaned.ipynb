# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import LineString, MultiLineString
import ast
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster


# %matplotlib inline

# %%
may_trips = pd.read_pickle('../data/may_trips.pkl')
june_trips = pd.read_pickle('../data/june_trips.pkl')
july_trips = pd.read_pickle('../data/july_trips.pkl')

# %%
july_trips.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-07-01 00:02:52.213000        Bird       BRD5179  PoweredZSHKJ
# 1  2019-07-01 00:02:52.213000        Bird       BRD5177  Powered22JF6
# 2  2019-07-01 00:02:52.213000        Bird       BRD5176  Powered22JF6
# 3  2019-07-01 00:02:52.213000        Bird       BRD5178  PoweredIB2CC
# 4  2019-07-01 00:02:52.213000        Bird       BRD5180  PoweredW4G7R
#
#    tripDistance  startLatitude  startLongitude  endLatitude  endLongitude  \
# 0           0.0        36.1775        -86.7516      36.1778      -86.7514
# 1           0.0        36.1627        -86.7711      36.1627      -86.7711
# 2           0.0        36.1627        -86.7713      36.1627      -86.7713
# 3           0.0        36.1525        -86.7988      36.1525      -86.7988
# 4           0.0        36.1578        -86.7760      36.1575      -86.7758
#
#                                            tripRoute  \
# ...

# %%
july_trips.tail()
# Out:
#                pubTimeStamp companyName tripRecordNum  \
# 134921  2019-08-01 04:53:48        JUMP          JMP3
# 134922  2019-08-01 04:53:48        JUMP          JMP2
# 134923  2019-08-01 04:53:48        JUMP          JMP1
# 134924  2019-08-01 07:04:00        JUMP         JMP35
# 134925  2019-08-01 07:04:00        JUMP         JMP34
#
#                                              sumdID  tripDistance  \
# 134921  Powered5614e4fc-1971-5e5c-a545-0fd88cd3331d        7075.2
# 134922  Powereda4712099-5e55-5332-996c-d6e5c910535d        1320.0
# 134923  Poweredb8a3a269-d1ca-571f-9b2f-89b7399b5537        7920.0
# 134924  Poweredf077a919-d569-5e70-8ca7-71d179ffacf9       20433.6
# 134925  Powered784fcc92-bd1a-5f6a-8314-b02aa21b4bfa       14889.6
#
#         startLatitude  startLongitude  endLatitude  endLongitude  \
# 134921      36.154633      -86.798340    36.149220    -86.813980
# 134922      36.153015      -86.783585    36.152843    -86.779594
# ...

# %%
july_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134669 entries, 0 to 134925
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   pubTimeStamp         134669 non-null  object
#  1   companyName          134669 non-null  object
#  2   tripRecordNum        134669 non-null  object
#  3   sumdID               134669 non-null  object
#  4   tripDistance         134669 non-null  float64
#  5   startLatitude        134669 non-null  float64
#  6   startLongitude       134669 non-null  float64
#  7   endLatitude          134669 non-null  float64
#  8   endLongitude         134669 non-null  float64
#  9   tripRoute            134669 non-null  object
#  10  create_dt            134669 non-null  object
#  11  startDateTime_clean  134669 non-null  datetime64[ns]
#  12  endDateTime_clean    134669 non-null  datetime64[ns]
#  13  duration_clean       134669 non-null  timedelta64[ns]
# ...

# %%
july_trips.tripRoute.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         [[36.177438,-86.751861],[36.177425,-86.751987]...
# 1           [[36.162718,-86.771102],[36.162718,-86.771102]]
# 2         [[36.162734,-86.77122],[36.162706,-86.771325],...
# 3                                  [[36.152499,-86.798708]]
# 4                                  [[36.157523,-86.775794]]
#                                 ...
# 134921    [["36.154631","-86.798341"],["36.154631","-86....
# 134922    [["36.153016","-86.783586"],["36.153016","-86....
# 134923    [["36.153685","-86.784578"],["36.153685","-86....
# 134924    [["36.155736","-86.775181"],["36.155531","-86....
# 134925    [["36.160051","-86.77672"],["36.160051","-86.7...
# Name: tripRoute, Length: 134669, dtype: object>

# %%
june_trips.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-06-01 00:05:46.817000        Bird       BRD3572  PoweredSPI1T
# 1  2019-06-01 00:05:46.817000        Bird       BRD3571  Powered2I3MS
# 2         2019-06-01 00:09:54      Gotcha          GOT1    Powered327
# 3  2019-06-01 00:10:46.957000        Bird       BRD3610  Powered8U1A6
# 4  2019-06-01 00:10:46.957000        Bird       BRD3612  PoweredSPI1T
#
#    tripDistance  startLatitude  startLongitude  endLatitude  endLongitude  \
# 0    328.084000      36.164400       -86.78070    36.163600    -86.780200
# 1   4921.260000      36.175300       -86.79430    36.175300    -86.794300
# 2     12.426575      36.161501       -86.77601    36.152529    -86.783742
# 3      0.000000      36.164000       -86.78070    36.163100    -86.779700
# 4    656.168000      36.165000       -86.77990    36.165900    -86.777800
#
#                                            tripRoute  \
# ...

# %%
june_trips.tail()
# Out:
#                pubTimeStamp companyName tripRecordNum  \
# 205622  2019-07-01 19:58:07        JUMP         JMP56
# 205623  2019-07-01 19:58:07        JUMP         JMP53
# 205624  2019-07-01 19:58:07        JUMP         JMP52
# 205625  2019-07-01 19:58:07        JUMP         JMP54
# 205626  2019-07-01 19:58:07        JUMP         JMP50
#
#                                              sumdID  tripDistance  \
# 205622  Powered2c1eeca5-26f4-5283-bbcd-5f46b19b7681       40708.8
# 205623  Poweredac7200ea-c5a4-5362-94a8-03e4d2255104       36854.4
# 205624  Powered3f96a82d-9641-58b6-b6db-b80f746a24cd       62356.8
# 205625  Poweredc2d0a425-86dd-5664-a036-d770559391bb       44880.0
# 205626  Powered1b56f557-adce-5c68-a98b-ab1ef41c7dcc       32472.0
#
#         startLatitude  startLongitude  endLatitude  endLongitude  \
# 205622      36.153070       -86.78393    36.160503     -86.77805
# 205623      36.162140       -86.77515    36.166332     -86.76144
# ...

# %%
june_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196197 entries, 0 to 205626
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   pubTimeStamp         196197 non-null  object
#  1   companyName          196197 non-null  object
#  2   tripRecordNum        196197 non-null  object
#  3   sumdID               196197 non-null  object
#  4   tripDistance         196197 non-null  float64
#  5   startLatitude        196197 non-null  float64
#  6   startLongitude       196197 non-null  float64
#  7   endLatitude          196197 non-null  float64
#  8   endLongitude         196197 non-null  float64
#  9   tripRoute            196197 non-null  object
#  10  create_dt            196197 non-null  object
#  11  startDateTime_clean  196197 non-null  datetime64[ns]
#  12  endDateTime_clean    196197 non-null  datetime64[ns]
#  13  duration_clean       196197 non-null  timedelta64[ns]
# ...

# %%
june_trips.tripRoute.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         [[36.164679,-86.781089],[36.163693,-86.78011],...
# 1         [[36.175367,-86.794232],[36.175367,-86.794232]...
# 2                       [["36.16149","-86.77605000000001"]]
# 3                                  [[36.163168,-86.779639]]
# 4         [[36.164951,-86.779836],[36.16494,-86.779456],...
#                                 ...
# 205622    [["36.153068","-86.783928"],["36.153063","-86....
# 205623    [["36.160706","-86.773443"],["36.160706","-86....
# 205624    [["36.156838","-86.781036"],["36.156845","-86....
# 205625    [["36.152695","-86.79713"],["36.152695","-86.7...
# 205626    [["36.164546","-86.776913"],["36.164546","-86....
# Name: tripRoute, Length: 196197, dtype: object>

# %%
may_trips.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum         sumdID  \
# 0  2019-05-01 00:00:55.423000        Bird       BRD2134   Powered9EAJL
# 1  2019-05-01 00:03:33.147000        Lyft          LFT5  Powered296631
# 2  2019-05-01 00:05:55.570000        Bird       BRD2168   Powered7S2UU
# 3  2019-05-01 00:05:55.570000        Bird       BRD2166   PoweredZIIVX
# 4  2019-05-01 00:05:55.570000        Bird       BRD2165   PoweredJ7MB3
#
#    tripDistance  startLatitude  startLongitude  endLatitude  endLongitude  \
# 0     958.00528       36.15710       -86.80360     36.15660     -86.80670
# 1    1371.39112       36.15797       -86.77896     36.16054     -86.77689
# 2    2296.58800       36.15470       -86.78180     36.15650     -86.78680
# 3    1200.78744       36.14940       -86.77950     36.15310     -86.77960
# 4     351.04988       36.17780       -86.78660     36.17740     -86.78760
#
#                                            tripRoute  \
# ...

# %%
may_trips.tail()
# Out:
#                       pubTimeStamp companyName tripRecordNum          sumdID  \
# 224633  2019-06-01 00:52:05.920000        SPIN        SPI715  Powered9174710
# 224634  2019-06-01 08:52:23.433000        SPIN        SPI464  Powered7025869
# 224693  2019-06-01 17:02:41.270000        SPIN        SPI667  Powered9642505
# 224694  2019-06-01 19:42:46.580000        SPIN        SPI291  Powered6661538
# 224968  2019-06-13 05:17:41.630000        SPIN        SPI146  Powered5750098
#
#         tripDistance  startLatitude  startLongitude  endLatitude  \
# 224633    2024.27828      36.147385      -86.811784    36.149966
# 224634    3336.61428      36.158557      -86.767873    36.158770
# 224693      49.21260      36.149462      -86.806266    36.149580
# 224694   12283.46496      36.149732      -86.814452    36.163070
# 224968   21551.83796      36.148668      -86.813511    36.147776
#
#         endLongitude                                          tripRoute  \
# ...

# %%
may_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199984 entries, 0 to 224968
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   pubTimeStamp         199984 non-null  object
#  1   companyName          199984 non-null  object
#  2   tripRecordNum        199984 non-null  object
#  3   sumdID               199984 non-null  object
#  4   tripDistance         199984 non-null  float64
#  5   startLatitude        199984 non-null  float64
#  6   startLongitude       199984 non-null  float64
#  7   endLatitude          199984 non-null  float64
#  8   endLongitude         199984 non-null  float64
#  9   tripRoute            199984 non-null  object
#  10  create_dt            199984 non-null  object
#  11  startDateTime_clean  199984 non-null  datetime64[ns]
#  12  endDateTime_clean    199984 non-null  datetime64[ns]
#  13  duration_clean       199984 non-null  timedelta64[ns]
# ...

# %%
may_trips.tripRoute.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         [[36.157235,-86.803612],[36.157235,-86.80362],...
# 1         [[36.15797,-86.77896],[36.15795,-86.77873],[36...
# 2            [[36.155068,-86.782124],[36.156597,-86.78675]]
# 3         [[36.149741,-86.779344],[36.149741,-86.779327]...
# 4         [[36.177699,-86.786477],[36.177711,-86.786469]...
#                                 ...
# 224633    [[36.14996642413616,-86.805699379889091],[36.1...
# 224634    [[36.15877,-86.77919],[36.15877,-86.77919],[36...
# 224693    [[36.149494461748887,-86.806152407160781],[36....
# 224694    [[36.16307,-86.77621],[36.16307,-86.77621],[36...
# 224968    [[36.147775779365219,-86.740436729892863],[36....
# Name: tripRoute, Length: 199984, dtype: object>

# %%
may_trips = may_trips.loc[may_trips['duration_min'] < 39.16]
may_trips = may_trips.loc[may_trips['duration_min'] > 0]
may_trips = may_trips.loc[may_trips['tripDistance'] < 52800]
may_trips = may_trips.loc[may_trips['tripDistance'] > 0]
june_trips = june_trips.loc[june_trips['duration_min'] < 38.75]
june_trips = june_trips.loc[june_trips['duration_min'] > 0]
june_trips = june_trips.loc[june_trips['tripDistance'] < 52800]
june_trips = june_trips.loc[june_trips['tripDistance'] > 0]
july_trips = july_trips.loc[july_trips['duration_min'] < 41.42]
july_trips = july_trips.loc[july_trips['duration_min'] > 0]
july_trips = july_trips.loc[july_trips['tripDistance'] < 52800]
july_trips = july_trips.loc[july_trips['tripDistance'] > 0]

# %%
july_trips = july_trips.sort_values(['tripDistance'], ascending=True)

# %%
july_trips = july_trips.reset_index()
july_trips.head()
# Out:
#     index                pubTimeStamp companyName tripRecordNum  \
# 0   12783         2019-07-04 17:45:18      Gotcha         GOT27
# 1   65770         2019-07-14 23:11:32      Gotcha         GOT47
# 2    4609  2019-07-02 01:54:58.853000        Lime     LIM786115
# 3   63818  2019-07-14 19:57:02.330000        Lime     LIM801077
# 4  104394  2019-07-25 12:58:35.557000        Lime     LIM814126
#
#                  sumdID  tripDistance  startLatitude  startLongitude  \
# 0            Powered638      2.428921      36.170997      -86.785147
# 1           Powered1576      2.896352      36.160829      -86.777607
# 2  Powered6GHEMWO6YRJIP      2.943043      36.168093      -86.783159
# 3  PoweredA2MMMLCRLSMPF      2.943256      36.162035      -86.774165
# 4  PoweredVIEIPVJSNPOCQ      2.943348      36.159993      -86.776596
#
#    endLatitude  endLongitude  \
# 0    36.162945    -86.776372
# 1    36.158247    -86.784045
# 2    36.168088    -86.783151
# 3    36.162422    -86.774302
# ...

# %%
july_trips.tail()
# Out:
#         index                pubTimeStamp companyName tripRecordNum  \
# 97933  105212  2019-07-25 17:58:37.793000        Lime     LIM814405
# 97934   83537  2019-07-19 23:57:55.540000        Lime     LIM807337
# 97935   99896  2019-07-23 20:58:24.093000        Lime     LIM812351
# 97936   97611  2019-07-22 20:58:13.157000        Lime     LIM811677
# 97937  101767  2019-07-24 15:58:28.037000        Lime     LIM813149
#
#                      sumdID  tripDistance  startLatitude  startLongitude  \
# 97933  PoweredGGWJJVFWJC72J  51206.252297      36.163791      -86.780808
# 97934  Powered4VFF5VL4F75NH  51451.952521      36.128783      -86.798459
# 97935  PoweredJQVKWGMSQZ3RO  51620.574413      36.100304      -86.799772
# 97936  PoweredTBGIRQ5IOW2KR  51767.884777      36.160527      -86.778177
# 97937  Powered5BW4GPYGBMUTL  52621.408883      36.165405      -86.781621
#
#        endLatitude  endLongitude  \
# 97933    36.160835    -86.778863
# 97934    36.134320    -86.780693
# ...

# %%
june_trips = june_trips.sort_values(['tripDistance'], ascending=True)

# %%
june_trips = june_trips.reset_index()
june_trips.head()
# Out:
#     index         pubTimeStamp companyName tripRecordNum       sumdID  \
# 0  122697  2019-06-16 06:44:37      Gotcha         GOT23   Powered673
# 1     404  2019-06-01 01:18:37      Gotcha         GOT12   Powered789
# 2    1455  2019-06-01 03:07:05      Gotcha         GOT39  Powered2143
# 3   56032  2019-06-08 03:54:02      Gotcha         GOT28   Powered754
# 4   78886  2019-06-10 03:03:13      Gotcha         GOT10  Powered2340
#
#    tripDistance  startLatitude  startLongitude  endLatitude  endLongitude  \
# 0      0.076653      36.151881      -86.792676    36.151880    -86.792677
# 1      0.102276      36.143678      -86.806358    36.143670    -86.806363
# 2      0.163755      36.154079      -86.784680    36.155403    -86.775595
# 3      0.436972      36.161817      -86.775259    36.161812    -86.775187
# 4      0.844915      36.154118      -86.784453    36.154169    -86.784463
#
#                                            tripRoute  \
# ...

# %%
june_trips.tail()
# Out:
#          index                pubTimeStamp    companyName tripRecordNum  \
# 151572   37295         2019-06-05 06:45:22  Bolt Mobility      BOL00148
# 151573   54556  2019-06-08 01:18:29.503000           Bird       BRD3855
# 151574   28534  2019-06-03 23:14:04.983000           Bird       BRD2590
# 151575  160733  2019-06-23 00:53:41.253000           Lime         LIM83
# 151576   70262  2019-06-09 04:51:39.323000           Lime        LIM655
#
#                                               sumdID  tripDistance  \
# 151572  Powered-1d88938b-8196-bd85-c06a-5be82c9a270b    42290.0300
# 151573                                  PoweredJIHRC    42650.9200
# 151574                                  PoweredUQ142    44947.5080
# 151575                          PoweredEAOQMIQZ5UIVS    45330.8136
# 151576                          PoweredZION27DRWBC5F    51931.7832
#
#         startLatitude  startLongitude  endLatitude  endLongitude  \
# ...

# %%
may_trips = may_trips.sort_values(['tripDistance'], ascending=True)

# %%
may_trips = may_trips.reset_index()
may_trips.head()
# Out:
#     index                pubTimeStamp companyName tripRecordNum  \
# 0  183743         2019-05-26 18:10:46      Gotcha         GOT65
# 1  220304         2019-05-31 16:12:35      Gotcha         GOT50
# 2   55296  2019-05-09 19:53:52.850000        Lime       LIM1450
# 3   65338  2019-05-11 15:47:01.003000        Lime       LIM1061
# 4   59767  2019-05-10 17:35:27.533000        Lime       LIM1799
#
#                  sumdID  tripDistance  startLatitude  startLongitude  \
# 0            Powered380      0.083756      36.156305      -86.776061
# 1            Powered616      0.213107      36.148513      -86.811590
# 2  Powered32ZPJVMT2JNJP      0.304800      36.178559      -86.749774
# 3  PoweredQPPZNSUIXWYSN      0.304800      36.176202      -86.756816
# 4  Powered6QMXAPVIN7JVB      0.304800      36.175321      -86.788105
#
#    endLatitude  endLongitude  \
# 0    36.156305    -86.776060
# 1    36.148511    -86.811587
# 2    36.177053    -86.750044
# 3    36.179294    -86.756576
# ...

# %%
may_trips.tail()
# Out:
#          index                pubTimeStamp companyName tripRecordNum  \
# 166640  155133  2019-05-24 06:49:17.303000        Lime       LIM1137
# 166641   56258  2019-05-09 23:01:28.860000        Bird       BRD1141
# 166642  155317  2019-05-24 08:49:18.227000        Lime       LIM1213
# 166643  124953  2019-05-19 06:43:45.400000        Lyft       LFT1404
# 166644  137374  2019-05-21 01:22:15.973000        SPIN         SPI32
#
#                       sumdID  tripDistance  startLatitude  startLongitude  \
# 166640  PoweredCFP6MH5XYRIN4   39976.54800      36.232434      -86.718057
# 166641          PoweredKCTSP   40682.41600      36.185500      -86.730800
# 166642  PoweredMMPY2XUGLYKCV   41334.79920      36.151584      -86.784383
# 166643         Powered297087   41446.85172      36.121480      -86.794750
# 166644        Powered6776606   43333.33472      36.166119      -86.780940
#
#         endLatitude  endLongitude  \
# 166640    36.170484    -86.761728
# ...

# %%
a = []
for row_index, row_value in july_trips.iterrows():
    routelist = ast.literal_eval(july_trips.loc[row_index,'tripRoute'])
    if len(routelist) > 2:
        if isinstance(routelist[0][0], float): 
            a.append(LineString(routelist).length)
        else:
            a.append(LineString(np.array(routelist,dtype=np.float32)).length)
    else:
        a.append(0)
july_trips['routeDistance']= a

#print(str(row_value['tripDistance'])+' | '+ str(test))
#np.array(ast.literal_eval(july_trips.loc[56,'tripRoute']),dtype=np.float32)

# %%
a = []
for row_index, row_value in may_trips.iterrows():
    routelist = ast.literal_eval(may_trips.loc[row_index,'tripRoute'])
    if len(routelist) > 2:
        if isinstance(routelist[0][0], float): 
            a.append(LineString(routelist).length)
        else:
            a.append(LineString(np.array(routelist,dtype=np.float32)).length)
    else:
        a.append(0)
may_trips['routeDistance']= a

# %%
a = []
for row_index, row_value in june_trips.iterrows():
    routelist = ast.literal_eval(june_trips.loc[row_index,'tripRoute'])
    if len(routelist) > 2:
        if isinstance(routelist[0][0], float): 
            a.append(LineString(routelist).length)
        else:
            a.append(LineString(np.array(routelist,dtype=np.float32)).length)
    else:
        a.append(0)
june_trips['routeDistance']= a

# %% [markdown]
# for row_index, row_value in july_trips.iterrows():
#     print(row_index)
#     routelist = ast.literal_eval(row_value['tripRoute'])
#     if isinstance(routelist[0][0], float):
#         july_trips[row_index]['tripRoute'] = routelist
#     else:
#         july_trips[row_index]['tripRoute'] = np.array(routelist,dtype=np.float32)

# %%
may_trips.head()

# %%
june_trips.head()
