# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#this is a python magic function to automatically show matplotlib plots
# %matplotlib inline

# %%
july_trip = pd.read_csv('../data/july_trip.csv')

# %%
july = pd.read_pickle('../data/july.pkl')

# %%
july_trip.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-07-01 00:02:52.213000        Bird       BRD5179  PoweredZSHKJ
# 1  2019-07-01 00:02:52.213000        Bird       BRD5177  Powered22JF6
# 2  2019-07-01 00:02:52.213000        Bird       BRD5176  Powered22JF6
# 3  2019-07-01 00:02:52.213000        Bird       BRD5178  PoweredIB2CC
# 4  2019-07-01 00:02:52.213000        Bird       BRD5180  PoweredW4G7R
#
#    tripDuration  tripDistance            startDate        startTime  \
# 0           2.0           0.0  2019-07-01 00:00:00  00:01:32.290000
# 1           0.0           0.0  2019-07-01 00:00:00  00:02:38.640000
# 2           1.0           0.0  2019-07-01 00:00:00  00:03:04.333333
# 3           1.0           0.0  2019-07-01 00:00:00  00:02:06.963333
# 4           2.0           0.0  2019-07-01 00:00:00  00:01:19.843333
#
#                endDate          endTime  startLatitude  startLongitude  \
# ...

# %%
july_trip.tail()
# Out:
#                pubTimeStamp companyName tripRecordNum  \
# 134921  2019-08-01 04:53:48        JUMP          JMP3
# 134922  2019-08-01 04:53:48        JUMP          JMP2
# 134923  2019-08-01 04:53:48        JUMP          JMP1
# 134924  2019-08-01 07:04:00        JUMP         JMP35
# 134925  2019-08-01 07:04:00        JUMP         JMP34
#
#                                              sumdID  tripDuration  \
# 134921  Powered5614e4fc-1971-5e5c-a545-0fd88cd3331d     17.497950
# 134922  Powereda4712099-5e55-5332-996c-d6e5c910535d      3.154917
# 134923  Poweredb8a3a269-d1ca-571f-9b2f-89b7399b5537     18.440650
# 134924  Poweredf077a919-d569-5e70-8ca7-71d179ffacf9    142.345610
# 134925  Powered784fcc92-bd1a-5f6a-8314-b02aa21b4bfa    209.409650
#
#         tripDistance            startDate startTime              endDate  \
# 134921        7075.2  2019-07-31 00:00:00  23:47:43  2019-08-01 00:00:00
# 134922        1320.0  2019-07-31 00:00:00  23:57:19  2019-08-01 00:00:00
# ...

# %%
july_trip.shape
# Out:
# (134926, 16)

# %%
july_trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134926 entries, 0 to 134925
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    134926 non-null  object
#  1   companyName     134926 non-null  object
#  2   tripRecordNum   134926 non-null  object
#  3   sumdID          134926 non-null  object
#  4   tripDuration    134926 non-null  float64
#  5   tripDistance    134926 non-null  float64
#  6   startDate       134926 non-null  object
#  7   startTime       134926 non-null  object
#  8   endDate         134926 non-null  object
#  9   endTime         134926 non-null  object
#  10  startLatitude   134926 non-null  float64
#  11  startLongitude  134926 non-null  float64
#  12  endLatitude     134926 non-null  float64
#  13  endLongitude    134926 non-null  float64
#  14  tripRoute       134926 non-null  object
#  15  create_dt       134926 non-null  object
# dtypes: float64(6), object(10)
# ...

# %%
july_trip.sumdID.value_counts()
# Out:
# PoweredUNKNOWN          327
# Powered5N5J5BJDODHYX    141
# PoweredOEHCPCAUHESR5    134
# PoweredIHGSNSRXCZ2ZG    128
# Powered5BW4GPYGBMUTL    126
#                        ...
# PoweredCRLCH              1
# PoweredMEJEH              1
# PoweredGK9VY              1
# PoweredJ2ZEW3VRV34OK      1
# PoweredDBL2I              1
# Name: sumdID, Length: 5585, dtype: int64

# %%
july_trip.describe()
# Out:
#         tripDuration  tripDistance  startLatitude  startLongitude  \
# count  134926.000000  1.349260e+05  134926.000000   134926.000000
# mean       97.097264  5.333994e+03      36.156738      -86.785144
# std      1722.548585  1.406051e+05       0.010914        0.013987
# min       -19.358267 -2.032480e+07      35.853200      -86.890850
# 25%         5.000000  3.280840e+02      36.150938      -86.793142
# 50%        10.148442  2.956037e+03      36.157200      -86.782100
# 75%        21.250550  6.916011e+03      36.162900      -86.776691
# max    512619.000000  3.188448e+07      36.299569      -86.366200
#
#          endLatitude   endLongitude
# count  134926.000000  134926.000000
# mean       36.156680     -86.785514
# std         0.118461       0.396499
# min         0.000000    -122.673729
# 25%        36.151014     -86.792596
# 50%        36.157680     -86.781523
# 75%        36.162800     -86.776546
# max        51.045409       0.000000

# %%
#How many scooters had tripDistance less than or equal to 0 ft
zero_rides = july_trip.loc[july_trip.tripDistance <= 0.0]
zero_rides
# Out:
#                       pubTimeStamp companyName tripRecordNum  \
# 0       2019-07-01 00:02:52.213000        Bird       BRD5179
# 1       2019-07-01 00:02:52.213000        Bird       BRD5177
# 2       2019-07-01 00:02:52.213000        Bird       BRD5176
# 3       2019-07-01 00:02:52.213000        Bird       BRD5178
# 4       2019-07-01 00:02:52.213000        Bird       BRD5180
# ...                            ...         ...           ...
# 134790  2019-07-31 23:59:31.363000        Lime     LIM824007
# 134849  2019-08-01 00:00:06.593000        Bird       BRD1819
# 134850  2019-08-01 00:00:06.593000        Bird       BRD1818
# 134851  2019-08-01 00:00:06.593000        Bird       BRD1820
# 134913  2019-08-01 00:59:26.133000        Lime     LIM824104
#
#                       sumdID  tripDuration  tripDistance            startDate  \
# 0               PoweredZSHKJ           2.0           0.0  2019-07-01 00:00:00
# ...

# %%
zero_rides.tripDistance.value_counts()
# Out:
#  0.000000e+00    27462
# -7.634515e+05        1
# -9.337271e+06        1
# -2.032480e+07        1
# -1.990092e+07        1
# Name: tripDistance, dtype: int64

# %%
zero_rides.describe()
# Out:
#        tripDuration  tripDistance  startLatitude  startLongitude  \
# count  27466.000000  2.746600e+04   27466.000000    27466.000000
# mean       7.967690 -1.832318e+03      36.157138      -86.784821
# std        9.922618  1.807019e+05       0.010590        0.013837
# min        0.000000 -2.032480e+07      35.853200      -86.863300
# 25%        3.000000  0.000000e+00      36.151500      -86.792200
# 50%        5.000000  0.000000e+00      36.157400      -86.781700
# 75%       10.000000  0.000000e+00      36.163000      -86.776700
# max      384.000000  0.000000e+00      36.213197      -86.366200
#
#         endLatitude  endLongitude
# count  27466.000000  27466.000000
# mean      36.155668    -86.782803
# std        0.218806      0.557640
# min        0.000000   -118.469800
# 25%       36.151400    -86.792200
# 50%       36.157600    -86.781700
# 75%       36.162900    -86.776700
# max       36.225600      0.000000

# %%
july_trip.tripDistance.value_counts()
# Out:
# 0.000000        27462
# 328.084000        930
# 1312.336000       830
# 656.168000        810
# 984.252000        801
#                 ...
# 2369.287516         1
# 773.307239          1
# 3597.528792         1
# 33579.400000        1
# 6232.881771         1
# Name: tripDistance, Length: 44770, dtype: int64

# %%
day1 = july_trip.query('startDate == "2019-07-01 00:00:00" and endDate == "2019-07-01 00:00:00"')
day1
# Out:
#                     pubTimeStamp companyName tripRecordNum  \
# 0     2019-07-01 00:02:52.213000        Bird       BRD5179
# 1     2019-07-01 00:02:52.213000        Bird       BRD5177
# 2     2019-07-01 00:02:52.213000        Bird       BRD5176
# 3     2019-07-01 00:02:52.213000        Bird       BRD5178
# 4     2019-07-01 00:02:52.213000        Bird       BRD5180
# ...                          ...         ...           ...
# 4245  2019-07-01 23:59:07.750000        SPIN        SPI204
# 4246  2019-07-01 23:59:20.367000        Lyft        LFT759
# 4247  2019-07-01 23:59:20.860000        Lyft        LFT760
# 4740         2019-07-02 04:54:18        JUMP        JMP210
# 4748         2019-07-02 04:54:18        JUMP        JMP211
#
#                                            sumdID  tripDuration  tripDistance  \
# 0                                    PoweredZSHKJ      2.000000       0.00000
# 1                                    Powered22JF6      0.000000       0.00000
# ...

# %%
day1_plus = july_trip.query('startDate == "2019-07-01 00:00:00" and endDate == "2019-07-02 00:00:00"')
day1_plus
# Out:
#                     pubTimeStamp companyName tripRecordNum  \
# 4236  2019-07-01 23:58:58.087000        Bird       BRD3124
# 4238  2019-07-01 23:58:58.087000        Bird       BRD3122
# 4241  2019-07-01 23:58:58.087000        Bird       BRD3130
# 4243  2019-07-01 23:58:58.087000        Bird       BRD3123
# 4248  2019-07-02 00:00:06.523000        Lyft          LFT1
# ...                          ...         ...           ...
# 4742         2019-07-02 04:54:18        JUMP          JMP4
# 4745         2019-07-02 04:54:18        JUMP          JMP7
# 4747         2019-07-02 04:54:18        JUMP          JMP1
# 4755         2019-07-02 06:48:07        JUMP         JMP24
# 4759         2019-07-02 06:48:07        JUMP         JMP29
#
#                                            sumdID  tripDuration  tripDistance  \
# 4236                                 PoweredBMAAV      3.000000       0.00000
# 4238                                 PoweredWSITQ      2.000000       0.00000
# ...

# %%
day1.companyName.value_counts()
# Out:
# Bird             2079
# Lime             1077
# Lyft              720
# SPIN              178
# Bolt Mobility     152
# JUMP               37
# Gotcha              3
# Name: companyName, dtype: int64

# %%
day1.describe()
# Out:
#        tripDuration  tripDistance  startLatitude  startLongitude  endLatitude  \
# count   4246.000000   4246.000000    4246.000000     4246.000000  4246.000000
# mean      62.247229   4012.472349      36.156964      -86.784696    36.156960
# std      389.300944   6022.885810       0.011013        0.013953     0.011508
# min        0.000000      0.000000      36.065160      -86.843800    36.065353
# 25%        4.730458      0.000000      36.151300      -86.791292    36.151216
# 50%        9.000000   1953.434935      36.157809      -86.781300    36.157905
# 75%       18.000000   5541.338760      36.163077      -86.776753    36.163140
# max     9954.000000  78740.160000      36.198450      -86.686832    36.222200
#
#        endLongitude
# count   4246.000000
# mean     -86.784434
# std        0.014474
# min      -86.880283
# 25%      -86.791400
# 50%      -86.781278
# 75%      -86.776562
# max      -86.687084

# %%
day1.sumdID.value_counts()
# Out:
# Powered6XGTBTHERKIAE                           12
# PoweredUNKNOWN                                 10
# PoweredHJU5G62RQJZ42                            9
# PoweredPVZEMNE2ENQRI                            9
# PoweredTBGIRQ5IOW2KR                            9
#                                                ..
# Powered7590016                                  1
# Powered0fc82c7f-9fb5-5f9b-b11d-f9415d92e561     1
# PoweredK1TFW                                    1
# PoweredFH7D2                                    1
# Powered2X7Y6                                    1
# Name: sumdID, Length: 2050, dtype: int64
